# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# #### Answer -

# %% [markdown]
# Flask Framewor is used to make API.
#
# ##### Advantages of Flask framework :-
#
# * There is a built-in development server and a fast debugger provided.
# * Lightweight.
# * Request dispatching using REST.
# * Support for unit testing is built-in.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# #### Answer -

# %% [markdown]
# ![image.png](attachment:6ce2cbbb-5582-4641-a096-adabb631d100.png)

# %% [markdown]
# ![image.png](attachment:61f6272a-97db-4184-aa93-61926a1b4b34.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# #### Answer -

# %% [markdown]
# App routing provides the route to reach any function by url. @app. route() is a Python decorator that Flask provides to assign URLs in our app to functions easily.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
#
# Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# #### Answer -

# %% [markdown]
# ![image.png](attachment:5fc1ecfe-fab7-49ba-801b-d505a7a19b90.png)

# %% [markdown]
# ![image.png](attachment:5fa2c3a6-0ddc-49ef-a1c7-1059a39b0cf8.png)

# %% [markdown]
# ![image.png](attachment:435a5506-1b51-4c11-b977-b18255b51a2d.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# #### Answer -

# %% [markdown]
# I am not able to answer this question because I have not done this kind of study yet so please email me the solution and explain it.
