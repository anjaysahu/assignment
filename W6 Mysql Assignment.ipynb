# %% [markdown]
# Q1. What is a database? Differentiate between SQL and NoSQL databases.

# %% [markdown]
# #### Answer -

# %% [markdown]
# A database is a structured collection of data that is organised in such away that it can be easily accessed, managed and upadated.
#
# ##### Difference between SQL and NoSQL databases -
#
# SQL databases are vertically scalable, while NoSQL databases are horizontally scalable. SQL databases are table-based, while NoSQL databases are document, key-value, graph, or wide-column stores. SQL databases are better for multi-row transactions, while NoSQL is better for unstructured data like documents or JSON

# %% [markdown]
# Q2. What is DDL? Explain why CREATE, DROP, ALTER, and TRUNCATE are used with an example.

# %% [markdown]
# #### Answer -

# %% [markdown]
# DDL stands for Data Definition Language.
# **CREATE -**  This command is used to create the database or its objects.

# %% [markdown]
# ![image.png](attachment:8e037e7d-ee0b-47f3-9f1c-8769cfdd6eb4.png)

# %% [markdown]
# **DROP -** This command is used to delete objects from the database.

# %% [markdown]
# ![image.png](attachment:be0f4c5f-6cfb-4b28-bb24-ecef7327d717.png)

# %% [markdown]
# **ALTER -** This is used to alter the structure of the database.

# %% [markdown]
# ![image.png](attachment:3c3ff164-796a-4644-99d0-24eeb87381c8.png)

# %% [markdown]
# **TRUNCATE -** This is used to remove all records from a table, including all spaces allocated for the records are removed.

# %% [markdown]
# ![image.png](attachment:f06a4d46-dc55-4bba-8250-613b51388a3a.png)

# %% [markdown]
# Q3. What is DML? Explain INSERT, UPDATE, and DELETE with an example.

# %% [markdown]
# #### Answer -

# %% [markdown]
# DML stands for Data Mainupulation Lamguage.
# **INSERT -** INSERT is used to insert data into a table.

# %% [markdown]
# ![image.png](attachment:68de484f-c569-417a-8412-b88f90e1705e.png)

# %% [markdown]
# **UPDATE -** UPDATE is used to update existing data within a table.

# %% [markdown]
# ![image.png](attachment:cc5c4c38-c8ca-4353-b73d-4f55286d8cc4.png)

# %% [markdown]
# **DELETE -** DELETE is used to delete records from a database table.

# %% [markdown]
# ![image.png](attachment:10133da3-d0cb-40ae-9784-f7769eefaa85.png)

# %% [markdown]
# Q4. What is DQL? Explain SELECT with an example.

# %% [markdown]
# #### Answer -

# %% [markdown]
# DQL stands for Data Query Language.
# **SELECT -** It is used to retrieve data from the database.

# %% [markdown]
# ![image.png](attachment:0afc4dd8-c866-406e-b0c8-85cddb0e5e38.png)

# %% [markdown]
# Q5. Explain Primary Key and Foreign Key.

# %% [markdown]
# #### Answer -

# %% [markdown]
# I am not able to answer this question because I have not done this kind of study yet so please email me the solution and explain it.

# %% [markdown]
# Q6. Write a python code to connect MySQL to python. Explain the cursor() and execute() method.

# %% [markdown]
# #### Answer -

# %% [markdown]
# ![image.png](attachment:bdfdccdc-0c03-49cf-a104-b1007509192a.png)

# %% [markdown]
# __cursor()__ - A cursor is an object that allows us to interact with the database.
# **execute()** - The execute() method is used to execute SQL queries.

# %% [markdown]
# Q7. Give the order of execution of SQL clauses in an SQL query.

# %% [markdown]
# #### Answer -

# %% [markdown]
# I am not able to answer this question because I have not done this kind of study yet so please email me the solution and explain it.
